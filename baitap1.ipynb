# %% [markdown]
# <a href="https://colab.research.google.com/github/nhatlinhdinhtran/code1511-/blob/main/baitap1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dtb=float(input("Nhap diem trung binh :"))
if (dtb <5):
  print("Yeu");
elif (dtb<7) and (dtb>=5):
  print("Trung binh")
elif (dtb <8) and (dtb>=7):
  print("Kha")
elif (dtb <9) and (dtb>=8):
  print("Gioi")
else :
  print("Xuat sac")
# Out:
# Nhap diem trung binh :5.6
# Trung binh

# %%
counter = 1
n = 5
#definite loop with 5 iterations
while counter <= n:
  print("Hello world!!!")
#increase counter
counter = counter + 1
#next task
print("Finished!!!")
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# Hello world!!!
# ...
